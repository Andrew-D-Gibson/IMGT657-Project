# %%
import numpy as np
import tensorflow as tf

def mnist_dataset(batch_size):
    (x_train, y_train), _ = tf.keras.datasets.mnist.load_data()
    # The `x` arrays are in uint8 and have values in the [0, 255] range.
    # You need to convert them to float32 with values in the [0, 1] range.
    x_train = x_train / np.float32(255)
    y_train = y_train.astype(np.int64)
    train_dataset = tf.data.Dataset.from_tensor_slices(
        (x_train, y_train)).shuffle(60000).repeat().batch(batch_size)
    return train_dataset


def build_and_compile_cnn_model():
    model = tf.keras.Sequential([
        tf.keras.layers.InputLayer(input_shape=(28, 28)),
        tf.keras.layers.Reshape(target_shape=(28, 28, 1)),
        tf.keras.layers.Conv2D(32, 3, activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(10)
    ])
    model.compile(
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
        metrics=['accuracy'])
    return model
# Out:
# 2023-08-11 13:02:43.928210: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-08-11 13:02:43.977882: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-11 13:02:44.672933: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import json
import os

def train_func_distributed():
    per_worker_batch_size = 64
    # This environment variable will be set by Ray Train.
    tf_config = json.loads(os.environ['TF_CONFIG'])
    num_workers = len(tf_config['cluster']['worker'])

    strategy = tf.distribute.MultiWorkerMirroredStrategy()

    global_batch_size = per_worker_batch_size * num_workers
    multi_worker_dataset = mnist_dataset(global_batch_size)

    with strategy.scope():
        # Model building/compiling need to be within `strategy.scope()`.
        multi_worker_model = build_and_compile_cnn_model()

    multi_worker_model.fit(multi_worker_dataset, epochs=3, steps_per_epoch=70)

# %%
from ray.train.tensorflow import TensorflowTrainer
from ray.air.config import ScalingConfig

# For GPU Training, set `use_gpu` to True.
use_gpu = False

trainer = TensorflowTrainer(train_func_distributed, scaling_config=ScalingConfig(num_workers=4, use_gpu=use_gpu))

result = trainer.fit()
print(result.metrics)
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-08-11 13:04:27</td></tr>
# <tr><td>Running for: </td><td>00:00:24.72        </td></tr>
# <tr><td>Memory:      </td><td>11.1/31.1 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 5.0/32 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                   </th><th>status    </th><th>loc                </th></tr>
# </thead>
# <tbody>
# <tr><td>TensorflowTrainer_12319_00000</td><td>TERMINATED</td><td>172.31.108.40:38188</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2023-08-11 13:04:02,320	INFO data_parallel_trainer.py:404 -- GPUs are detected in your Ray cluster, but GPU training is not enabled for this trainer. To enable GPU training, make sure to set `use_gpu` to True in your scaling config.
# (raylet) bash: /home/drew/miniconda3/envs/imgt/lib/libtinfo.so.6: no version information available (required by bash)
# (pid=38188) 2023-08-11 13:04:04.770853: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (TrainTrainable pid=38188) GPUs are detected in your Ray cluster, but GPU training is not enabled for this trainer. To enable GPU training, make sure to set `use_gpu` to True in your scaling config.
# (TensorflowTrainer pid=38188) GPUs are detected in your Ray cluster, but GPU training is not enabled for this trainer. To enable GPU training, make sure to set `use_gpu` to True in your scaling config.
# (raylet) bash: /home/drew/miniconda3/envs/imgt/lib/libtinfo.so.6: no version information available (required by bash)
# (raylet) bash: /home/drew/miniconda3/envs/imgt/lib/libtinfo.so.6: no version information available (required by bash)
# (raylet) bash: /home/drew/miniconda3/envs/imgt/lib/libtinfo.so.6: no version information available (required by bash)
# (raylet) bash: /home/drew/miniconda3/envs/imgt/lib/libtinfo.so.6: no version information available (required by bash)
# (TensorflowTrainer pid=38188) Starting distributed worker processes: ['38235 (172.31.108.40)', '38236 (172.31.108.40)', '38237 (172.31.108.40)', '38238 (172.31.108.40)']
# (RayTrainWorker pid=38237) 2023-08-11 13:04:10.220710: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (RayTrainWorker pid=38236) 2023-08-11 13:04:07.965963: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT [repeated 4x across cluster]
# (RayTrainWorker pid=38237) 2023-08-11 13:04:11.256306: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:786] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (RayTrainWorker pid=38237) op: "TensorSliceDataset"
# (RayTrainWorker pid=38237) input: "Placeholder/_0"
# (RayTrainWorker pid=38237) input: "Placeholder/_1"
# (RayTrainWorker pid=38237) attr {
# (RayTrainWorker pid=38237)   key: "Toutput_types"
# (RayTrainWorker pid=38237)   value {
# (RayTrainWorker pid=38237)     list {
# (RayTrainWorker pid=38237)       type: DT_FLOAT
# (RayTrainWorker pid=38237)       type: DT_INT64
# (RayTrainWorker pid=38237)     }
# (RayTrainWorker pid=38237)   }
# (RayTrainWorker pid=38237) }
# (RayTrainWorker pid=38237) attr {
# (RayTrainWorker pid=38237)   key: "_cardinality"
# (RayTrainWorker pid=38237)   value {
# (RayTrainWorker pid=38237)     i: 60000
# (RayTrainWorker pid=38237)   }
# (RayTrainWorker pid=38237) }
# (RayTrainWorker pid=38237) attr {
# (RayTrainWorker pid=38237)   key: "is_files"
# (RayTrainWorker pid=38237)   value {
# (RayTrainWorker pid=38237)     b: false
# (RayTrainWorker pid=38237)   }
# (RayTrainWorker pid=38237) }
# (RayTrainWorker pid=38237) attr {
# (RayTrainWorker pid=38237)   key: "metadata"
# (RayTrainWorker pid=38237)   value {
# (RayTrainWorker pid=38237)     s: "\n\024TensorSliceDataset:0"
# (RayTrainWorker pid=38237)   }
# (RayTrainWorker pid=38237) }
# (RayTrainWorker pid=38237) attr {
# (RayTrainWorker pid=38237)   key: "output_shapes"
# (RayTrainWorker pid=38237)   value {
# (RayTrainWorker pid=38237)     list {
# (RayTrainWorker pid=38237)       shape {
# (RayTrainWorker pid=38237)         dim {
# (RayTrainWorker pid=38237)           size: 28
# (RayTrainWorker pid=38237)         }
# (RayTrainWorker pid=38237)         dim {
# (RayTrainWorker pid=38237)           size: 28
# (RayTrainWorker pid=38237)         }
# (RayTrainWorker pid=38237)       }
# (RayTrainWorker pid=38237)       shape {
# (RayTrainWorker pid=38237)       }
# (RayTrainWorker pid=38237)     }
# (RayTrainWorker pid=38237)   }
# (RayTrainWorker pid=38237) }
# (RayTrainWorker pid=38237) attr {
# (RayTrainWorker pid=38237)   key: "replicate_on_split"
# (RayTrainWorker pid=38237)   value {
# (RayTrainWorker pid=38237)     b: false
# (RayTrainWorker pid=38237)   }
# (RayTrainWorker pid=38237) }
# (RayTrainWorker pid=38237) experimental_type {
# (RayTrainWorker pid=38237)   type_id: TFT_PRODUCT
# (RayTrainWorker pid=38237)   args {
# (RayTrainWorker pid=38237)     type_id: TFT_DATASET
# (RayTrainWorker pid=38237)     args {
# (RayTrainWorker pid=38237)       type_id: TFT_PRODUCT
# (RayTrainWorker pid=38237)       args {
# (RayTrainWorker pid=38237)         type_id: TFT_TENSOR
# (RayTrainWorker pid=38237)         args {
# (RayTrainWorker pid=38237)           type_id: TFT_FLOAT
# (RayTrainWorker pid=38237)         }
# (RayTrainWorker pid=38237)       }
# (RayTrainWorker pid=38237)       args {
# (RayTrainWorker pid=38237)         type_id: TFT_TENSOR
# (RayTrainWorker pid=38237)         args {
# (RayTrainWorker pid=38237)           type_id: TFT_INT64
# (RayTrainWorker pid=38237)         }
# (RayTrainWorker pid=38237)       }
# (RayTrainWorker pid=38237)     }
# (RayTrainWorker pid=38237)   }
# (RayTrainWorker pid=38237) }
# (RayTrainWorker pid=38237)
# (RayTrainWorker pid=38237) 2023-08-11 13:04:11.395123: W tensorflow/core/framework/dataset.cc:807] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# (RayTrainWorker pid=38237) Epoch 1/3
#  2/70 [..............................] - ETA: 4s - loss: 9.1739 - accuracy: 0.3828
#  3/70 [>.............................] - ETA: 3s - loss: 9.1661 - accuracy: 0.4167
#  4/70 [>.............................] - ETA: 3s - loss: 9.1645 - accuracy: 0.4336
#  5/70 [=>............................] - ETA: 3s - loss: 9.1632 - accuracy: 0.4500
#  7/70 [==>...........................] - ETA: 3s - loss: 9.1649 - accuracy: 0.4643
#  9/70 [==>...........................] - ETA: 3s - loss: 9.1591 - accuracy: 0.4688
# 11/70 [===>..........................] - ETA: 3s - loss: 9.1558 - accuracy: 0.4773
# 13/70 [====>.........................] - ETA: 3s - loss: 9.1509 - accuracy: 0.4988
# 15/70 [=====>........................] - ETA: 3s - loss: 9.1523 - accuracy: 0.5031
# 17/70 [======>.......................] - ETA: 3s - loss: 9.1451 - accuracy: 0.5257
# 18/70 [======>.......................] - ETA: 3s - loss: 9.1429 - accuracy: 0.5365
# 20/70 [=======>......................] - ETA: 2s - loss: 9.1398 - accuracy: 0.5500
# 22/70 [========>.....................] - ETA: 2s - loss: 9.1356 - accuracy: 0.5639
# 24/70 [=========>....................] - ETA: 2s - loss: 9.1314 - accuracy: 0.5781
# 26/70 [==========>...................] - ETA: 2s - loss: 9.1265 - accuracy: 0.6052
# 28/70 [===========>..................] - ETA: 2s - loss: 9.1221 - accuracy: 0.6295
# 29/70 [===========>..................] - ETA: 2s - loss: 9.1198 - accuracy: 0.6439
# 31/70 [============>.................] - ETA: 2s - loss: 9.1138 - accuracy: 0.6689
# 33/70 [=============>................] - ETA: 2s - loss: 9.1112 - accuracy: 0.6795
# 35/70 [==============>...............] - ETA: 2s - loss: 9.1082 - accuracy: 0.6888
# 37/70 [==============>...............] - ETA: 1s - loss: 9.1046 - accuracy: 0.7057
# 39/70 [===============>..............] - ETA: 1s - loss: 9.1000 - accuracy: 0.7232
# 41/70 [================>.............] - ETA: 1s - loss: 9.0961 - accuracy: 0.7359
# 43/70 [=================>............] - ETA: 1s - loss: 9.0918 - accuracy: 0.7496
# 45/70 [==================>...........] - ETA: 1s - loss: 9.0883 - accuracy: 0.7663
# 47/70 [===================>..........] - ETA: 1s - loss: 9.0846 - accuracy: 0.7806
# 48/70 [===================>..........] - ETA: 1s - loss: 9.0822 - accuracy: 0.7887
# 49/70 [====================>.........] - ETA: 1s - loss: 9.0802 - accuracy: 0.7972
# 52/70 [=====================>........] - ETA: 1s - loss: 9.0753 - accuracy: 0.8170
# 54/70 [======================>.......] - ETA: 0s - loss: 9.0714 - accuracy: 0.8319
# 56/70 [=======================>......] - ETA: 0s - loss: 9.0673 - accuracy: 0.8471
# 58/70 [=======================>......] - ETA: 0s - loss: 9.0626 - accuracy: 0.8691
# 59/70 [========================>.....] - ETA: 0s - loss: 9.0598 - accuracy: 0.8769
# 61/70 [=========================>....] - ETA: 0s - loss: 9.0562 - accuracy: 0.8929
# 63/70 [==========================>...] - ETA: 0s - loss: 9.0538 - accuracy: 0.9033
# 64/70 [==========================>...] - ETA: 0s - loss: 9.0518 - accuracy: 0.9119
# 66/70 [===========================>..] - ETA: 0s - loss: 9.0478 - accuracy: 0.9264
# 68/70 [============================>.] - ETA: 0s - loss: 9.0446 - accuracy: 0.9393
# 69/70 [============================>.] - ETA: 0s - loss: 9.0422 - accuracy: 0.9470
# 70/70 [==============================] - 5s 60ms/step - loss: 2.2600 - accuracy: 0.2390
# (RayTrainWorker pid=38235) Epoch 2/3 [repeated 4x across cluster]
#  6/70 [=>............................] - ETA: 3s - loss: 8.8721 - accuracy: 1.5911
#  7/70 [==>...........................] - ETA: 3s - loss: 8.8716 - accuracy: 1.5848
# 10/70 [===>..........................] - ETA: 3s - loss: 8.8740 - accuracy: 1.5719
# 10/70 [===>..........................] - ETA: 3s - loss: 8.8740 - accuracy: 1.5719
#  2/70 [..............................] - ETA: 4s - loss: 8.8874 - accuracy: 1.5547 [repeated 7x across cluster]
#  4/70 [>.............................] - ETA: 3s - loss: 9.1645 - accuracy: 0.4336 [repeated 3x across cluster]
#  4/70 [>.............................] - ETA: 4s - loss: 8.8778 - accuracy: 1.5977 [repeated 5x across cluster]
# 19/70 [=======>......................] - ETA: 3s - loss: 8.8593 - accuracy: 1.5979
#  5/70 [=>............................] - ETA: 3s - loss: 9.1632 - accuracy: 0.4500 [repeated 3x across cluster]
#  7/70 [==>...........................] - ETA: 3s - loss: 9.1649 - accuracy: 0.4643 [repeated 3x across cluster]
#  9/70 [==>...........................] - ETA: 3s - loss: 9.1591 - accuracy: 0.4688 [repeated 3x across cluster]
# 11/70 [===>..........................] - ETA: 3s - loss: 9.1558 - accuracy: 0.4773 [repeated 3x across cluster]
# 25/70 [=========>....................] - ETA: 2s - loss: 8.8497 - accuracy: 1.6256
# 13/70 [====>.........................] - ETA: 3s - loss: 8.8734 - accuracy: 1.5769 [repeated 7x across cluster]
# 27/70 [==========>...................] - ETA: 2s - loss: 8.8445 - accuracy: 1.6372
# 15/70 [=====>........................] - ETA: 3s - loss: 8.8636 - accuracy: 1.5958 [repeated 7x across cluster]
# 29/70 [===========>..................] - ETA: 2s - loss: 8.8395 - accuracy: 1.6482
# 17/70 [======>.......................] - ETA: 3s - loss: 8.8600 - accuracy: 1.6048 [repeated 7x across cluster]
# 18/70 [======>.......................] - ETA: 3s - loss: 8.8600 - accuracy: 1.6042 [repeated 7x across cluster]
# 32/70 [============>.................] - ETA: 2s - loss: 8.8355 - accuracy: 1.6592
# 20/70 [=======>......................] - ETA: 2s - loss: 9.1398 - accuracy: 0.5500 [repeated 3x across cluster]
# 34/70 [=============>................] - ETA: 2s - loss: 8.8296 - accuracy: 1.6801
# 22/70 [========>.....................] - ETA: 2s - loss: 8.8562 - accuracy: 1.6115 [repeated 7x across cluster]
# 24/70 [=========>....................] - ETA: 2s - loss: 8.8514 - accuracy: 1.6224 [repeated 7x across cluster]
# 38/70 [===============>..............] - ETA: 1s - loss: 8.8183 - accuracy: 1.7118
# 26/70 [==========>...................] - ETA: 2s - loss: 9.1265 - accuracy: 0.6052 [repeated 3x across cluster]
# 40/70 [================>.............] - ETA: 1s - loss: 8.8128 - accuracy: 1.7246
# 28/70 [===========>..................] - ETA: 2s - loss: 9.1221 - accuracy: 0.6295 [repeated 3x across cluster]
# 41/70 [================>.............] - ETA: 1s - loss: 8.8104 - accuracy: 1.7309
# 29/70 [===========>..................] - ETA: 2s - loss: 9.1198 - accuracy: 0.6439 [repeated 3x across cluster]
# 31/70 [============>.................] - ETA: 2s - loss: 8.8361 - accuracy: 1.6583 [repeated 7x across cluster]
# 33/70 [=============>................] - ETA: 2s - loss: 9.1112 - accuracy: 0.6795 [repeated 3x across cluster]
# 35/70 [==============>...............] - ETA: 2s - loss: 9.1082 - accuracy: 0.6888 [repeated 3x across cluster]
# 49/70 [====================>.........] - ETA: 1s - loss: 8.7940 - accuracy: 1.7695
# 36/70 [==============>...............] - ETA: 2s - loss: 8.8238 - accuracy: 1.6940 [repeated 7x across cluster]
# 39/70 [===============>..............] - ETA: 1s - loss: 9.1000 - accuracy: 0.7232 [repeated 3x across cluster]
# 41/70 [================>.............] - ETA: 1s - loss: 9.0961 - accuracy: 0.7359 [repeated 3x across cluster]
# 43/70 [=================>............] - ETA: 1s - loss: 8.8055 - accuracy: 1.7402 [repeated 7x across cluster]
# 57/70 [=======================>......] - ETA: 0s - loss: 8.7759 - accuracy: 1.8070
# 45/70 [==================>...........] - ETA: 1s - loss: 8.8025 - accuracy: 1.7479 [repeated 7x across cluster]
# 59/70 [========================>.....] - ETA: 0s - loss: 8.7714 - accuracy: 1.8149
# 47/70 [===================>..........] - ETA: 1s - loss: 8.7984 - accuracy: 1.7586 [repeated 7x across cluster]
# 48/70 [===================>..........] - ETA: 1s - loss: 9.0822 - accuracy: 0.7887 [repeated 3x across cluster]
# 50/70 [====================>.........] - ETA: 1s - loss: 8.7918 - accuracy: 1.7753 [repeated 11x across cluster]
# 62/70 [=========================>....] - ETA: 0s - loss: 8.7635 - accuracy: 1.8264
# 64/70 [==========================>...] - ETA: 0s - loss: 8.7592 - accuracy: 1.8357
# 52/70 [=====================>........] - ETA: 1s - loss: 8.7874 - accuracy: 1.7852 [repeated 7x across cluster]
# 54/70 [======================>.......] - ETA: 0s - loss: 8.7834 - accuracy: 1.7931 [repeated 7x across cluster]
# 56/70 [=======================>......] - ETA: 0s - loss: 8.7778 - accuracy: 1.8050 [repeated 7x across cluster]
# 70/70 [==============================] - ETA: 0s - loss: 8.7477 - accuracy: 1.8545
# 58/70 [=======================>......] - ETA: 0s - loss: 9.0626 - accuracy: 0.8691 [repeated 3x across cluster]
# 70/70 [==============================] - 4s 61ms/step - loss: 2.1869 - accuracy: 0.4636
#  1/70 [..............................] - ETA: 4s - loss: 8.5567 - accuracy: 2.0156
# 59/70 [========================>.....] - ETA: 0s - loss: 9.0598 - accuracy: 0.8769 [repeated 3x across cluster]
#  2/70 [..............................] - ETA: 5s - loss: 8.5173 - accuracy: 2.1641
# 61/70 [=========================>....] - ETA: 0s - loss: 8.7675 - accuracy: 1.8197 [repeated 7x across cluster]
# 63/70 [==========================>...] - ETA: 0s - loss: 9.0538 - accuracy: 0.9033 [repeated 3x across cluster]
# 64/70 [==========================>...] - ETA: 0s - loss: 9.0518 - accuracy: 0.9119 [repeated 3x across cluster]
# 66/70 [===========================>..] - ETA: 0s - loss: 8.7553 - accuracy: 1.8414 [repeated 7x across cluster]
# 68/70 [============================>.] - ETA: 0s - loss: 8.7521 - accuracy: 1.8474 [repeated 7x across cluster]
# 69/70 [============================>.] - ETA: 0s - loss: 9.0422 - accuracy: 0.9470 [repeated 3x across cluster]
# 12/70 [====>.........................] - ETA: 3s - loss: 8.5366 - accuracy: 2.1836
# 70/70 [==============================] - 5s 60ms/step - loss: 2.2600 - accuracy: 0.2390 [repeated 3x across cluster]
# (RayTrainWorker pid=38236) Epoch 3/3 [repeated 7x across cluster]
# 19/70 [=======>......................] - ETA: 3s - loss: 8.5102 - accuracy: 2.2105
#  6/70 [=>............................] - ETA: 4s - loss: 8.5365 - accuracy: 2.1745 [repeated 7x across cluster]
# 21/70 [========>.....................] - ETA: 2s - loss: 8.5067 - accuracy: 2.2165
#  9/70 [==>...........................] - ETA: 3s - loss: 8.8756 - accuracy: 1.5642 [repeated 9x across cluster]
# 22/70 [========>.....................] - ETA: 2s - loss: 8.5037 - accuracy: 2.2237
# 10/70 [===>..........................] - ETA: 3s - loss: 8.5438 - accuracy: 2.1922 [repeated 5x across cluster]
# 11/70 [===>..........................] - ETA: 3s - loss: 8.5380 - accuracy: 2.1918 [repeated 9x across cluster]
# 32/70 [============>.................] - ETA: 2s - loss: 8.4870 - accuracy: 2.2124
#  4/70 [>.............................] - ETA: 4s - loss: 8.5210 - accuracy: 2.1953 [repeated 4x across cluster]
# 20/70 [=======>......................] - ETA: 2s - loss: 8.8573 - accuracy: 1.6047 [repeated 7x across cluster]
# 35/70 [==============>...............] - ETA: 2s - loss: 8.4771 - accuracy: 2.2205
#  8/70 [==>...........................] - ETA: 3s - loss: 8.5433 - accuracy: 2.1855 [repeated 4x across cluster]
# 24/70 [=========>....................] - ETA: 2s - loss: 8.5028 - accuracy: 2.2109 [repeated 7x across cluster]
# 27/70 [==========>...................] - ETA: 2s - loss: 8.8445 - accuracy: 1.6372 [repeated 3x across cluster]
# 15/70 [=====>........................] - ETA: 3s - loss: 8.5231 - accuracy: 2.2031 [repeated 4x across cluster]
# 42/70 [=================>............] - ETA: 1s - loss: 8.4602 - accuracy: 2.2295
# 30/70 [===========>..................] - ETA: 2s - loss: 8.4920 - accuracy: 2.2130 [repeated 7x across cluster]
# 17/70 [======>.......................] - ETA: 3s - loss: 8.5181 - accuracy: 2.1976 [repeated 4x across cluster]
# 46/70 [==================>...........] - ETA: 1s - loss: 8.4505 - accuracy: 2.2425
# 32/70 [============>.................] - ETA: 2s - loss: 8.8355 - accuracy: 1.6592 [repeated 3x across cluster]
# 48/70 [===================>..........] - ETA: 1s - loss: 8.4441 - accuracy: 2.2487
# 34/70 [=============>................] - ETA: 2s - loss: 8.4808 - accuracy: 2.2224 [repeated 7x across cluster]
# 50/70 [====================>.........] - ETA: 1s - loss: 8.4387 - accuracy: 2.2491
# 38/70 [===============>..............] - ETA: 1s - loss: 8.8183 - accuracy: 1.7118 [repeated 3x across cluster]
# 26/70 [==========>...................] - ETA: 2s - loss: 8.4993 - accuracy: 2.2133 [repeated 4x across cluster]
# 53/70 [=====================>........] - ETA: 1s - loss: 8.4339 - accuracy: 2.2462
# 40/70 [================>.............] - ETA: 1s - loss: 8.8128 - accuracy: 1.7246 [repeated 3x across cluster]
# 28/70 [===========>..................] - ETA: 2s - loss: 8.4969 - accuracy: 2.2065 [repeated 4x across cluster]
# 55/70 [======================>.......] - ETA: 0s - loss: 8.4296 - accuracy: 2.2520
# 41/70 [================>.............] - ETA: 1s - loss: 8.8104 - accuracy: 1.7309 [repeated 3x across cluster]
# 49/70 [====================>.........] - ETA: 1s - loss: 8.7940 - accuracy: 1.7695 [repeated 3x across cluster]
# 37/70 [==============>...............] - ETA: 1s - loss: 8.4739 - accuracy: 2.2204 [repeated 4x across cluster]
# 39/70 [===============>..............] - ETA: 1s - loss: 8.4647 - accuracy: 2.2368 [repeated 4x across cluster]
# 41/70 [================>.............] - ETA: 1s - loss: 8.4606 - accuracy: 2.2367 [repeated 4x across cluster]
# 43/70 [=================>............] - ETA: 1s - loss: 8.4577 - accuracy: 2.2326
# 57/70 [=======================>......] - ETA: 0s - loss: 8.7759 - accuracy: 1.8070 [repeated 3x across cluster]
# 59/70 [========================>.....] - ETA: 0s - loss: 8.4187 - accuracy: 2.2609 [repeated 7x across cluster]
# Trial TensorflowTrainer_12319_00000 completed. Last result:
# 2023-08-11 13:04:27,038	INFO tune.py:1148 -- Total run time: 24.74 seconds (24.72 seconds for the tuning loop).
# 2023-08-11 13:04:27,040	WARNING experiment_analysis.py:916 -- Failed to read the results for 1 trials:
# - /home/drew/ray_results/TensorflowTrainer_2023-08-11_13-04-02/TensorflowTrainer_12319_00000_0_2023-08-11_13-04-02
# {'trial_id': '12319_00000', 'date': '2023-08-11_13-04-05', 'timestamp': 1691773445, 'pid': 38188, 'hostname': 'drew-lenovo', 'node_ip': '172.31.108.40', 'config': {}, 'done': True}

# %%
from ray.air import session, Checkpoint, ScalingConfig
from ray.train.tensorflow import TensorflowTrainer

import numpy as np

def train_func(config):
    import tensorflow as tf
    n = 100
    # create a toy dataset
    # data   : X - dim = (n, 4)
    # target : Y - dim = (n, 1)
    X = np.random.normal(0, 1, size=(n, 4))
    Y = np.random.uniform(0, 1, size=(n, 1))

    strategy = tf.distribute.MultiWorkerMirroredStrategy()
    with strategy.scope():
        # toy neural network : 1-layer
        model = tf.keras.Sequential([tf.keras.layers.Dense(1, activation="linear", input_shape=(4,))])
        model.compile(optimizer="Adam", loss="mean_squared_error", metrics=["mse"])

    for epoch in range(config["num_epochs"]):
        model.fit(X, Y, batch_size=20)
        checkpoint = Checkpoint.from_dict(
            dict(epoch=epoch, model_weights=model.get_weights())
        )
        session.report({}, checkpoint=checkpoint)

trainer = TensorflowTrainer(
    train_func,
    train_loop_config={"num_epochs": 5},
    scaling_config=ScalingConfig(num_workers=2),
)
result = trainer.fit()

print(result.checkpoint.to_dict())
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-08-11 13:20:25</td></tr>
# <tr><td>Running for: </td><td>00:00:10.64        </td></tr>
# <tr><td>Memory:      </td><td>8.2/31.1 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 3.0/32 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                   </th><th>status    </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>TensorflowTrainer_55de2_00000</td><td>TERMINATED</td><td>172.31.108.40:43760</td><td style="text-align: right;">     5</td><td style="text-align: right;">          5.3894</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2023-08-11 13:20:14,851	INFO data_parallel_trainer.py:404 -- GPUs are detected in your Ray cluster, but GPU training is not enabled for this trainer. To enable GPU training, make sure to set `use_gpu` to True in your scaling config.
# (raylet) bash: /home/drew/miniconda3/envs/imgt/lib/libtinfo.so.6: no version information available (required by bash)
# (pid=43760) 2023-08-11 13:20:17.404993: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (TrainTrainable pid=43760) GPUs are detected in your Ray cluster, but GPU training is not enabled for this trainer. To enable GPU training, make sure to set `use_gpu` to True in your scaling config.
# (TensorflowTrainer pid=43760) GPUs are detected in your Ray cluster, but GPU training is not enabled for this trainer. To enable GPU training, make sure to set `use_gpu` to True in your scaling config.
# (raylet) bash: /home/drew/miniconda3/envs/imgt/lib/libtinfo.so.6: no version information available (required by bash)
# (raylet) bash: /home/drew/miniconda3/envs/imgt/lib/libtinfo.so.6: no version information available (required by bash)
# (TensorflowTrainer pid=43760) Starting distributed worker processes: ['43833 (172.31.108.40)', '43834 (172.31.108.40)']
# (RayTrainWorker pid=43834) 2023-08-11 13:20:21.270200: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (RayTrainWorker pid=43834) 2023-08-11 13:20:21.587440: W tensorflow/core/framework/dataset.cc:807] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 5/5 [==============================] - 1s 13ms/step - loss: 1.6082 - mse: 1.6082
# 1/5 [=====>........................] - ETA: 0s - loss: 5.5933 - mse: 5.5933
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6369 - mse: 2.6369
# 2023-08-11 13:20:25,485	INFO tune.py:1148 -- Total run time: 10.66 seconds (10.63 seconds for the tuning loop).
# {'epoch': 4, 'model_weights': [array([[0.5412861 ],
#        [0.77299863],
#        [0.52936023],
#        [0.7033395 ]], dtype=float32), array([0.0204476], dtype=float32)], '_metadata': _CheckpointMetadata(checkpoint_type=<class 'ray.train.tensorflow.tensorflow_checkpoint.TensorflowCheckpoint'>, checkpoint_state={'_current_checkpoint_id': 4, '_flavor': None, '_h5_file_path': None}), '_preprocessor': None, '_ray_additional_checkpoint_files': {'.tune_metadata': b'././@PaxHeader0000000\x000000000\x000000000\x0000000000034\x0000000000000\x00010212\x00 xustar\x000028 mtime=1691774423.4461184\n ...

# %%
import ray
import tensorflow as tf

from ray.air import session
from ray.air.integrations.keras import ReportCheckpointCallback
from ray.train.tensorflow import TensorflowTrainer
from ray.air.config import ScalingConfig


# If using GPUs, set this to True.
use_gpu = False

a = 5
b = 10
size = 100


def build_model() -> tf.keras.Model:
    model = tf.keras.Sequential(
        [
            tf.keras.layers.InputLayer(input_shape=()),
            # Add feature dimension, expanding (batch_size,) to (batch_size, 1).
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(10),
            tf.keras.layers.Dense(1),
        ]
    )
    return model


def train_func(config: dict):
    batch_size = config.get("batch_size", 64)
    epochs = config.get("epochs", 3)

    strategy = tf.distribute.MultiWorkerMirroredStrategy()
    with strategy.scope():
        # Model building/compiling need to be within `strategy.scope()`.
        multi_worker_model = build_model()
        multi_worker_model.compile(
            optimizer=tf.keras.optimizers.SGD(learning_rate=config.get("lr", 1e-3)),
            loss=tf.keras.losses.mean_squared_error,
            metrics=[tf.keras.metrics.mean_squared_error],
        )

    dataset = session.get_dataset_shard("train")

    results = []
    for _ in range(epochs):
        tf_dataset = dataset.to_tf(
            feature_columns="x", label_columns="y", batch_size=batch_size
        )
        history = multi_worker_model.fit(
            tf_dataset, callbacks=[ReportCheckpointCallback()]
        )
        results.append(history.history)
    return results


config = {"lr": 1e-3, "batch_size": 32, "epochs": 4}

train_dataset = ray.data.from_items(
    [{"x": x / 200, "y": 2 * x / 200} for x in range(200)]
)
scaling_config = ScalingConfig(num_workers=2, use_gpu=use_gpu)
trainer = TensorflowTrainer(
    train_loop_per_worker=train_func,
    train_loop_config=config,
    scaling_config=scaling_config,
    datasets={"train": train_dataset},
)
result = trainer.fit()
print(result.metrics)
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-08-14 14:07:15</td></tr>
# <tr><td>Running for: </td><td>00:00:12.45        </td></tr>
# <tr><td>Memory:      </td><td>8.5/31.1 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 3.0/32 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                   </th><th>status    </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  loss</th><th style="text-align: right;">  mean_squared_error</th></tr>
# </thead>
# <tbody>
# <tr><td>TensorflowTrainer_5ee55_00000</td><td>TERMINATED</td><td>172.31.108.40:17290</td><td style="text-align: right;">     4</td><td style="text-align: right;">         7.13188</td><td style="text-align: right;">1.3967</td><td style="text-align: right;">              1.3967</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2023-08-14 14:07:03,003	INFO data_parallel_trainer.py:404 -- GPUs are detected in your Ray cluster, but GPU training is not enabled for this trainer. To enable GPU training, make sure to set `use_gpu` to True in your scaling config.
# (raylet) bash: /home/drew/miniconda3/envs/imgt/lib/libtinfo.so.6: no version information available (required by bash)
# (pid=17290) 2023-08-14 14:07:05.564784: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (TrainTrainable pid=17290) GPUs are detected in your Ray cluster, but GPU training is not enabled for this trainer. To enable GPU training, make sure to set `use_gpu` to True in your scaling config.
# (TensorflowTrainer pid=17290) GPUs are detected in your Ray cluster, but GPU training is not enabled for this trainer. To enable GPU training, make sure to set `use_gpu` to True in your scaling config.
# (raylet) bash: /home/drew/miniconda3/envs/imgt/lib/libtinfo.so.6: no version information available (required by bash)
# (raylet) bash: /home/drew/miniconda3/envs/imgt/lib/libtinfo.so.6: no version information available (required by bash)
# (TensorflowTrainer pid=17290) Starting distributed worker processes: ['17362 (172.31.108.40)', '17363 (172.31.108.40)']
# (RayTrainWorker pid=17362) 2023-08-14 14:07:09.456784: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (RayTrainWorker pid=17362) 2023-08-14 14:07:09.799534: W tensorflow/core/framework/dataset.cc:807] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# (raylet) bash: /home/drew/miniconda3/envs/imgt/lib/libtinfo.so.6: no version information available (required by bash)
# (SplitCoordinator pid=17454) Auto configuring locality_with_output=['c71245cc0888d6d76191a491cf572db0842a320d46f154a5269d46b0', 'c71245cc0888d6d76191a491cf572db0842a320d46f154a5269d46b0']
# (SplitCoordinator pid=17454) Executing DAG InputDataBuffer[Input] -> OutputSplitter[split(2, equal=True)]
# (SplitCoordinator pid=17454) Execution config: ExecutionOptions(resource_limits=ExecutionResources(cpu=None, gpu=None, object_store_memory=2000000000.0), locality_with_output=['c71245cc0888d6d76191a491cf572db0842a320d46f154a5269d46b0', 'c71245cc0888d6d76191a491cf572db0842a320d46f154a5269d46b0'], preserve_order=False, actor_locality_enabled=True, verbose_progress=False)
# (SplitCoordinator pid=17454) Tip: For detailed progress reporting, run `ray.data.DataContext.get_current().execution_options.verbose_progress = True`
# (RayTrainWorker pid=17363) 2023-08-14 14:07:08.751248: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (SplitCoordinator pid=17454) [dataset]: Run `pip install tqdm` to enable progress reporting.
#       1/Unknown - 1s 1s/step - loss: 0.0949 - mean_squared_error: 0.0949
#       6/Unknown - 1s 12ms/step - loss: 3.4796 - mean_squared_error: 3.4796
# (raylet) bash: /home/drew/miniconda3/envs/imgt/lib/libtinfo.so.6: no version information available (required by bash)
# 8/8 [==============================] - 2s 72ms/step - loss: 1.8815 - mean_squared_error: 1.8815
# (SplitCoordinator pid=17454) Executing DAG InputDataBuffer[Input] -> OutputSplitter[split(2, equal=True)]
# (SplitCoordinator pid=17454) Execution config: ExecutionOptions(resource_limits=ExecutionResources(cpu=None, gpu=None, object_store_memory=2000000000.0), locality_with_output=['c71245cc0888d6d76191a491cf572db0842a320d46f154a5269d46b0', 'c71245cc0888d6d76191a491cf572db0842a320d46f154a5269d46b0'], preserve_order=False, actor_locality_enabled=True, verbose_progress=False)
# (SplitCoordinator pid=17454) Tip: For detailed progress reporting, run `ray.data.DataContext.get_current().execution_options.verbose_progress = True`
#       4/Unknown - 0s 19ms/step - loss: 1.3588 - mean_squared_error: 1.3588
# (SplitCoordinator pid=17454) Executing DAG InputDataBuffer[Input] -> OutputSplitter[split(2, equal=True)]
# (SplitCoordinator pid=17454) Execution config: ExecutionOptions(resource_limits=ExecutionResources(cpu=None, gpu=None, object_store_memory=2000000000.0), locality_with_output=['c71245cc0888d6d76191a491cf572db0842a320d46f154a5269d46b0', 'c71245cc0888d6d76191a491cf572db0842a320d46f154a5269d46b0'], preserve_order=False, actor_locality_enabled=True, verbose_progress=False)
# (SplitCoordinator pid=17454) Tip: For detailed progress reporting, run `ray.data.DataContext.get_current().execution_options.verbose_progress = True`
#       4/Unknown - 0s 18ms/step - loss: 1.1859 - mean_squared_error: 1.1859
# (SplitCoordinator pid=17454) Executing DAG InputDataBuffer[Input] -> OutputSplitter[split(2, equal=True)]
# (SplitCoordinator pid=17454) Execution config: ExecutionOptions(resource_limits=ExecutionResources(cpu=None, gpu=None, object_store_memory=2000000000.0), locality_with_output=['c71245cc0888d6d76191a491cf572db0842a320d46f154a5269d46b0', 'c71245cc0888d6d76191a491cf572db0842a320d46f154a5269d46b0'], preserve_order=False, actor_locality_enabled=True, verbose_progress=False)
# (SplitCoordinator pid=17454) Tip: For detailed progress reporting, run `ray.data.DataContext.get_current().execution_options.verbose_progress = True`
# 2023-08-14 14:07:15,453	INFO tune.py:1148 -- Total run time: 12.56 seconds (12.45 seconds for the tuning loop).
# {'loss': 1.396697998046875, 'mean_squared_error': 1.396697998046875, 'timestamp': 1692036433, 'time_this_iter_s': 0.6089682579040527, 'should_checkpoint': True, 'done': True, 'training_iteration': 4, 'trial_id': '5ee55_00000', 'date': '2023-08-14_14-07-13', 'time_total_s': 7.131880760192871, 'pid': 17290, 'hostname': 'drew-lenovo', 'node_ip': '172.31.108.40', 'config': {'train_loop_config': {'lr': 0.001, 'batch_size': 32, 'epochs': 4}}, 'time_since_restore': 7.131880760192871, 'iterations_since_restore': 4, 'experiment_tag': '0'}
